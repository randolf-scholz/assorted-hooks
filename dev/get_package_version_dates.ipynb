# %% [markdown]
# ## Get list of all packages

# %%
import pkgutil
from importlib.metadata import metadata
from pandas import DataFrame, Index

packages = [pkg.name for pkg in pkgutil.iter_modules() if pkg.ispkg]
packages = sorted([pkg for pkg in packages if not pkg.startswith("_")])

# %%
x.metadata.keys()
# Out:
# ['Metadata-Version',
#  'Name',
#  'Version',
#  'Summary',
#  'Author',
#  'Author-email',
#  'License',
#  'Project-URL',
#  'Project-URL',
#  'Project-URL',
#  'Project-URL',
#  'Keywords',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Classifier',
#  'Requires-Python',
#  'Description-Content-Type',
#  'License-File',
#  'Requires-Dist',
#  'Provides-Extra',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Provides-Extra',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Provides-Extra',
#  'Requires-Dist',
#  'Provides-Extra',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Provides-Extra',
#  'Requires-Dist',
#  'Provides-Extra',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Requires-Dist',
#  'Provides-Extra',
#  'Requires-Dist',
#  'Description']

# %%
import importlib.metadata

packages = {
    x.name: (
        x.version,
        x.metadata["Summary"],
        x.metadata["License"],
    )
    for x in importlib.metadata.distributions()
}
local_packages = DataFrame.from_dict(
    packages, orient="index", columns=["Version", "Summary", "License"]
)
local_packages
# Out:
#                              Version  \
# ml-env                           0.8
# debugpy                        1.8.1
# black                         24.4.2
# hyperopt                       0.2.7
# holidays                        0.49
# ...                              ...
# networkx                         3.3
# memray                        1.12.0
# tensorflow-io-gcs-filesystem  0.37.0
# chex                          0.1.86
# optree                        0.11.0
#
#                                                                         Summary  \
# ml-env                           A collection of packages for a ML environment.
# debugpy                       An implementation of the Debug Adapter Protoco...
# black                                        The uncompromising code formatter.
# hyperopt                      Distributed Asynchronous Hyperparameter Optimi...
# holidays                              Generate and work with holidays in Python
# ...                                                                         ...
# networkx                      Python package for creating and manipulating g...
# memray                                A memory profiler for Python applications
# tensorflow-io-gcs-filesystem                                      TensorFlow IO
# chex                                            Chex: Testing made fun, in JAX!
# optree                                              Optimized PyTree Utilities.
#
#                                                                         License
# ml-env                        MIT License\n===========\n\nCopyright (c) 2021...
# debugpy                                                                     MIT
# black                                                                       MIT
# hyperopt                                                                    BSD
# holidays                      Copyright (c) Vacanza Team and individual cont...
# ...                                                                         ...
# networkx                                                                   None
# memray                                                               Apache 2.0
# tensorflow-io-gcs-filesystem                                               None
# chex                                                                 Apache 2.0
# optree                                              Apache License, Version 2.0
#
# [511 rows x 3 columns]

# %% [markdown]
# ## Validate Version number

# %%
import re

VERSION_PATTERN = r"""
    v?
    (?:
        (?:(?P<epoch>[0-9]+)!)?                           # epoch
        (?P<release>[0-9]+(?:\.[0-9]+)*)                  # release segment
        (?P<pre>                                          # pre-release
            [-_\.]?
            (?P<pre_l>(a|b|c|rc|alpha|beta|pre|preview))
            [-_\.]?
            (?P<pre_n>[0-9]+)?
        )?
        (?P<post>                                         # post release
            (?:-(?P<post_n1>[0-9]+))
            |
            (?:
                [-_\.]?
                (?P<post_l>post|rev|r)
                [-_\.]?
                (?P<post_n2>[0-9]+)?
            )
        )?
        (?P<dev>                                          # dev release
            [-_\.]?
            (?P<dev_l>dev)
            [-_\.]?
            (?P<dev_n>[0-9]+)?
        )?
    )
    (?:\+(?P<local>[a-z0-9]+(?:[-_\.][a-z0-9]+)*))?       # local version
"""

regex = re.compile(
    r"^\s*" + VERSION_PATTERN + r"\s*$",
    re.VERBOSE | re.IGNORECASE,
)


def is_canonical(version: str):
    return re.match(regex, version) is not None


for pkg in packages:
    if not is_canonical(packages[pkg][0]):
        print(pkg, packages[pkg][0])

# %% [markdown]
# ## Get Release Date

# %%
import aiohttp
from tqdm.asyncio import tqdm
from typing import Any


async def get_pypi_json(pkg: str, session: aiohttp.ClientSession) -> dict[str, Any]:
    url = f"https://pypi.org/pypi/{pkg}/json"
    async with session.get(url) as response:
        response.raise_for_status()
        return await response.json()


async def get_all_pypi_json(packages: list[str]) -> dict[str, dict[str, Any]]:
    async with aiohttp.ClientSession() as session:
        tasks = (get_pypi_json(pkg, session=session) for pkg in packages)
        responses = await tqdm.gather(*tasks)
        return {pkg: data for pkg, data in zip(packages, responses)}


# Usage example
pypi_data = await get_all_pypi_json(packages)
# print(len(pypi_data), pypi_data.keys())
# Out:
# 100%|██████████| 511/511 [00:01<00:00, 261.69it/s]
# 511 dict_keys(['ml-env', 'debugpy', 'black', 'hyperopt', 'holidays', 'tensorflow-datasets', 'sphinx-math-dollar', 'google-pasta', 'filelock', 'types-decorator', 'freetype-py', 'tabulate', 'types-pyOpenSSL', 'tbparse', 'certifi', 'lsprotocol', 'nbstripout', 'threadpoolctl', 'hdmedians', 'jupyterlab', 'cycler', 'nest-asyncio', 'types-chardet', 'sphinx-copybutton', 'fastjsonschema', 'labmaze', 'pure-eval', 'pylint', 'opencensus-context', 'protobuf', 'sortedcontainers', 'tzdata', 'pexpect', 'requests', 'jupytext', 'frozenlist', 'nvidia-cuda-nvrtc-cu12', 'types-docutils', 'pycryptodome', 'pyaml', 'nfoursid', 'greenlet', 'jeepney', 'bleach', 'h11', 'oyaml', 'importlib_metadata', 'types-cffi', 'pytz', 'jupyterlab_server', 'Cython', 'fsspec', 'liac-arff', 'structlog', 'scikit-bio', 'google-api-core', 'referencing', 'Sphinx', 'jupyter_packaging', 'jupyter-resource-usage', 'pluggy', 'jsonpointer', 'argon2-cffi-bindings', 'opt-einsum', 'jupyterlab-lsp', 'anytree', 'jaxlib', 'scikit-image', 'sphinxcontrib-devhelp', 'cmake', 'identify', 'executing', 'websocket-client', 'fs', 'types-urllib3', 'mdit-py-plugins', 'ipython', 'tensorflow', 'sphinx-autodoc-typehints', 'asciitree', 'nvidia-nvjitlink-cu12', 'annotated-types', 'ndindex', 'TestSlide', 'isoduration', 'setproctitle', 'pickleshare', 'alabaster', 'matplotlib-inline', 'httpcore', 'opencensus', 'dm-tree', 'pygls', 'multipledispatch', 'gast', 'stack-data', 'tokenize-rt', 'cachetools', 'ipywidgets', 'flatbuffers', 'pyparsing', 'statsmodels', 'notebook', 'seaborn', 'Babel', 'smart-open', 'numba', 'sphinxcontrib-htmlhelp', 'logical-unification', 'webcolors', 'jmp', 'pipdeptree', 'Mako', 'defusedxml', 'rlax', 'importlib_resources', 'scikit-network', 'jaraco.classes', 'google-auth', 'setuptools', 'arrow', 'Deprecated', 'iniconfig', 'pillow', 'types-Pygments', 'ply', 'fasteners', 'jupyter-events', 'plotly', 'darts', 'nvidia-cuda-runtime-cu12', 'plumbum', 'fastrlock', 'cffi', 'types-backports', 'nvidia-cusolver-cu12', 'charset-normalizer', 'scipy', 'tensorboard', 'packaging', 'nvidia-nccl-cu12', 'Werkzeug', 'ipydex', 'virtualenv', 'torchtext', 'et-xmlfile', 'nvidia-cusparse-cu12', 'miniKanren', 'pyre-extensions', 'ml-dtypes', 'slotscheck', 'json5', 'argon2-cffi', 'deprecation', 'aiohttp-cors', 'nvidia-nvtx-cu12', 'wandb', 'optuna', 'mccabe', 'autopep8', 'stdlib-list', 'cupy-cuda12x', 'torchmetrics', 'mypy-extensions', 'flax', 'colorlog', 'slicer', 'polars', 'torchvision', 'types-PyYAML', 'toolz', 'hsluv', 'jupyter_server_terminals', 'sphinx-automodapi', 'SQLAlchemy', 'joblib', 'array_record', 'nvidia-cudnn-cu12', 'py-spy', 'colorful', 'numpy', 'ipython-autotime', 'termcolor', 'types-setuptools', 'etils', 'typing-inspect', 'types-toml', 'msgpack', 'etuples', 'grpcio', 'pybadges', 'absl-py', 'typing_extensions', 'graphviz', 'httpx', 'nbdime', 'opencv-python', 'pkginfo', 'nvidia-cufft-cu12', 'yarl', 'nvidia-curand-cu12', 'aiohttp', 'widgetsnbextension', 'pyproject_hooks', 'contourpy', 'intervaltree', 'jsonschema-specifications', 'toml', 'fqdn', 'dm-haiku', 'zarr', 'marshmallow', 'pycodestyle', 'tables', 'cons', 'karma_sphinx_theme', 'rise', 'jupyter_client', 'cfgv', 'pyasn1_modules', 'docker-pycreds', 'gym-notices', 'Markdown', 'attrs', 'typeguard', 'numcodecs', 'coverage', 'ujson', 'idna', 'Pygments', 'py4j', 'distrax', 'promise', 'mistune', 'piccolo-theme', 'click', 'python-lsp-server', 'types-colorama', 'proto-plus', 'pytest-benchmark', 'cattrs', 'nbstripout-fast', 'numexpr', 'decorator', 'python-slugify', 'PyGithub', 'orbax-checkpoint', 'wrapt', 'portalocker', 'comm', 'terminado', 'tensorflow-probability', 'torch', 'py-cpuinfo', 'Send2Trash', 'openpyxl', 'jupyterlab_widgets', 'numpydoc', 'parso', 'anyio', 'odfpy', 'tifffile', 'pyarrow', 'lazy_loader', 'pydantic', 'cloudpickle', 'tensorflow-text', 'optax', 'nbqa', 'MarkupSafe', 'pyflakes', 'types-tabulate', 'keyring', 'rfc3986-validator', 'pmdarima', 'python-json-logger', 'jupyterlab-execute-time', 'sphinxcontrib-applehelp', 'tbats', 'imagesize', ...

# %%
import asyncio
import json
from urllib.request import urlopen


async def get_pypi_json(pkg: str) -> dict:
    url = f"https://pypi.org/pypi/{pkg}/json"
    loop = asyncio.get_event_loop()
    response = await loop.run_in_executor(None, urlopen, url)
    data = response.read()
    return json.loads(data)


async def get_all_pypi_json(packages: list[str]) -> dict:
    tasks = [get_pypi_json(pkg) for pkg in packages]
    responses = await asyncio.gather(*tasks)
    return {pkg: data for pkg, data in zip(packages, responses)}


# Usage example
pypi_data = await get_all_pypi_json(packages)
# print(pypi_data)

# %%
## summarize the data in DataFrame
from datetime import datetime
import warnings
from typing import TypeAlias

JSON: TypeAlias = dict[str, Any]


def get_release_version(version: str) -> tuple[int, ...]:
    match = re.match(regex, version)
    if match is None:
        warnings.warn(f"Invalid version: {version}")
        return (0,)
    return tuple(int(x) for x in match.group("release").split("."))


def get_release_date(releases: list[JSON]) -> datetime | None:
    uploads = [datetime.fromisoformat(release["upload_time"]) for release in releases]
    if not uploads:
        return None
    return min(uploads)


def get_lastest_version(pkg: str) -> tuple[str, datetime | None]:
    data = pypi_data[pkg]
    releases: dict[str, list[JSON]] = data["releases"]
    sorted_releases = sorted(releases, key=get_release_version)
    latest_release = sorted_releases[-1]
    return latest_release, get_release_date(releases[latest_release])


pypi_packages = {pkg: get_lastest_version(pkg) for pkg in pypi_data}
latest = DataFrame.from_dict(
    pypi_packages, orient="index", columns=["version", "date"]
).sort_values("date")
# Out:
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2004d
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2005e
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2005i
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2005k
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2005m
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2006g
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2006j
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2006p
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2007d
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2007f
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2007g
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2007i
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2007k
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2008g
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2008h
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2008i
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2009d
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2009e
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2009f
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2009g
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2009i
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2009j
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2009l
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2009n
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2009p
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2009u
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2010e
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2010g
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2010h
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2010k
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2010l
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2010o
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2011d
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2011e
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2011g
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2011h
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2011j
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2011k
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2011n
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2012d
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2012f
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2012g
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2012h
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2012j
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013d
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 0.7.1.fix1
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 0.7.4.svn.r2010
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 0.3.2d
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 0.3.2d.dev
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 0.3.2e.dev
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 0.3.2f
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 0.3.2f.dev
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 0.3.2g.dev
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 0.7.0d
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-02-16
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-02-23
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-03-11
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-05-21
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-06-05
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-06-26
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-08-04
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-10-04
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-10-12
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-10-21
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-10-22
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-10-23
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-10-24
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-10-25
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-10-26
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-11-29
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 2013-12-31
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 0.5.13-hg
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 0.8.0-final0
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 0.8.1-final0
#   warnings.warn(f"Invalid version: {version}")
# /tmp/ipykernel_315592/3506422797.py:9: UserWarning: Invalid version: 1.3.0.dev-r634
#   warnings.warn(f"Invalid version: {version}")

# %% [markdown]
# ## Check for unmaintained packages

# %%
deprecated = latest.loc[latest.date < "2022"]
print(deprecated)

# check pyproject.toml for deprecated packages
#  load pyproject.toml as string

with open("pyproject.toml", encoding="utf8") as file:
    pyproject = file.read()

# regex match dependencies
for name in deprecated.index:
    regex = re.compile(rf"{name}")
    # show match and line number and line
    for i, line in enumerate(pyproject.split("\n")):
        if regex.search(line):
            print(f"pyproject.toml:{i+1}: {line} ({name})")
# Out:
#                          version                date
# wget                         3.2 2015-10-22 15:26:37
# asciitree                  0.3.3 2016-09-05 19:10:42
# ipython-genutils           0.2.0 2017-03-13 22:12:25
# webencodings               0.5.1 2017-04-05 20:21:32
# ply                         3.11 2018-02-15 19:01:27
# aiohttp-cors               0.7.0 2018-03-06 15:45:42
# karma_sphinx_theme         0.0.8 2018-06-20 00:03:29
# pickleshare                0.7.5 2018-09-25 19:17:35
# wimpy                        0.6 2018-10-09 05:59:32
# docker-pycreds             0.4.0 2018-11-29 03:26:49
# sphinxcontrib-jsmath       1.0.1 2019-01-21 16:10:14
# text-unidecode               1.3 2019-08-30 21:36:45
# colorful                 0.6.0a1 2019-09-04 18:47:15
# aiohttp                  4.0.0a1 2019-10-09 11:29:30
# rfc3986-validator          0.1.1 2019-10-28 16:00:13
# promise                      2.3 2019-12-18 07:31:43
# astunparse                 1.6.3 2019-12-22 18:12:11
# odfpy                      1.4.1 2020-01-18 16:55:48
# google-pasta               0.2.0 2020-03-13 18:57:47
# deprecation                2.1.0 2020-04-20 14:23:36
# appdirs                    1.4.4 2020-05-11 07:59:49
# opencensus-context      0.2.dev0 2020-06-29 20:27:28
# opt-einsum                 3.3.0 2020-07-19 22:40:30
# intervaltree               3.1.0 2020-08-03 08:01:11
# oyaml                        1.0 2020-08-18 04:37:38
# liac-arff                  2.5.0 2020-08-31 18:59:16
# toml                      0.10.2 2020-11-01 01:40:20
# isoduration              20.11.0 2020-11-01 10:59:58
# ml-env                0.2.0.dev0 2020-11-01 19:29:03
# ptyprocess                 0.7.0 2020-12-28 15:15:28
# hdmedians                 0.14.2 2021-03-01 02:44:48
# fqdn                       1.5.1 2021-03-11 07:16:28
# et-xmlfile                 1.1.0 2021-04-26 13:26:03
# six                       1.16.0 2021-05-05 14:18:17
# rfc3339-validator          0.1.4 2021-05-12 16:37:52
# sortedcontainers           2.4.0 2021-05-16 22:03:41
# types-backports            0.1.3 2021-06-17 14:59:29
# httpx                    1.0.0b0 2021-09-14 08:48:25
# snowballstemmer            2.2.0 2021-11-16 18:38:34
# hyperopt                   0.2.7 2021-11-17 10:05:44
# argon2-cffi-bindings      21.2.0 2021-12-01 08:52:55
# py-redis                   1.1.1 2021-12-13 16:58:48
# pyproject.toml:227:     "opt-einsum>=3.3.0", (opt-einsum)
# pyproject.toml:510: opt-einsum = ">=3.3.0" (opt-einsum)
# pyproject.toml:13: name = "ml-env" (ml-env)
# pyproject.toml:255: documentation = "https://bvt-htbd.gitlab-pages.tu-berlin.de/kiwi/tf1/ml-env" (ml-env)
# pyproject.toml:256: homepage = "https://git.tu-berlin.de/bvt-htbd/kiwi/tf1/ml-env" (ml-env)
# pyproject.toml:265: name = "ml-env" (ml-env)
# pyproject.toml:274: documentation = "https://bvt-htbd.gitlab-pages.tu-berlin.de/kiwi/tf1/ml-env" (ml-env)
# pyproject.toml:275: homepage = "https://git.tu-berlin.de/bvt-htbd/kiwi/tf1/ml-env" (ml-env)
# pyproject.toml:244:     "sortedcontainers>=2.4.0", (sortedcontainers)
# pyproject.toml:526: sortedcontainers = ">=2.4.0" (sortedcontainers)
# pyproject.toml:217:     "hyperopt>=0.2.7", (hyperopt)
# pyproject.toml:500: hyperopt = ">=0.2.7" (hyperopt)
